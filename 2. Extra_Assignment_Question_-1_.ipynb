# %% [markdown]
# Extra_Assignment_Question_-1_

# %%
#print statement

print("Hope AI")
# Out:
# Hope AI

# %%
#Buy inputs

Institute_name: input("Enter your institute name? :")
# Out:
# Enter your institute name? : Hope AI

# %%
#Addition

a= int(input("a="))
b= int(input("b="))
Add = a+b

print("add =", Add)
# Out:
# a= 43
# b= 34
# add = 77

# %%
#Subtraction

a= int(input("a="))
b= int(input("b="))
Sub = a-b

print("Sub =", Sub)
# Out:
# a= 43
# b= 34
# Sub = 9

# %%
# Multiplication 

a= int(input("a="))
b= int(input("b="))
Mul = a*b

print("Mul =", Mul)
# Out:
# a= 63
# b= 97
# Mul = 6111

# %%
#Division

a= int(input("a="))
b= int(input("b="))
Div = a/b

print("Float Div =", Div)
# Out:
# a= 76
# b= 31
# Float Div = 2.4516129032258065

# %%
#Floor division

a= int(input("a="))
b= int(input("b="))
Floor_Div = a//b

print("Floor Div=", Floor_Div)
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
# Modulo

a= int(input("a="))
b= int(input("b="))
Modulo = a%b

print("Modulo=", Modulo)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
#Power

a= int(input("a="))
b= int(input("b="))
Power = a**b

print("Power =", Power)
# Out:
# a= 4
# b= 4
# Power = 256
